# %%
import re
import pandas as pd
import numpy as np
import tensorflow as tf
from fuzzywuzzy import fuzz
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.layers import Dense, Embedding, LSTM,Dropout,Bidirectional,GlobalMaxPooling1D

# %% [markdown]
# # load dataset

# %%
data = pd.read_csv('Bot Dataset.csv')
data.head()
# Out:
#       tag                                           Question  \
# 0  user 1                           Apa itu penyakit mental?
# 1  user 2           Siapa yang mempengaruhi penyakit mental?
# 2  user 3              Apa yang menyebabkan penyakit mental?
# 3  user 4  Apa saja tanda -tanda peringatan penyakit mental?
# 4  user 5        Bisakah orang dengan penyakit mental pulih?
#
#                                               Answer
# 0  Penyakit mental adalah kondisi kesehatan yang ...
# 1  Diperkirakan bahwa penyakit mental mempengaruh...
# 2  Diperkirakan bahwa penyakit mental mempengaruh...
# 3  Gejala gangguan kesehatan mental bervariasi te...
# 4  Ketika penyembuhan dari penyakit mental, ident...

# %% [markdown]
# # inisialisasi stop words

# %%
stopwords = []
with open('stopwords.txt', encoding='utf-8') as f:
    for line in f:
        stopwords.append(line.strip())

# %%
# fungsi untuk menghilangkan stopwords
def remove_stopwords(text):
    text = text.lower()
    text = re.sub('[^a-zA-Z0-9\s]', '', text)
    temp = re.sub(r'[.,’"\'-?:!;]', '', text)
    text = re.sub(r'^Apa|^Saya|^Aku|^maukah|^Siapa|^Bagaimana|^Dimana|^Kapan|^Kenapa|^Bisakah', '', text)
    words = [word for word in text.split() if word not in stopwords]
    return ' '.join(words)

# %%
# menghilangkan stopwords dari dataset
data['Question'] = data['Question'].apply(remove_stopwords)
print(data['Question'])
# Out:
# 0                             penyakit mental
# 1                mempengaruhi penyakit mental
# 2                 menyebabkan penyakit mental
# 3      tanda tanda peringatan penyakit mental
# 4                 orang penyakit mental pulih
#                         ...
# 153                                     stres
# 154                            berhasil hidup
# 155                                         p
# 156                           assalamualaikum
# 157                              teman curhat
# Name: Question, Length: 158, dtype: object

# %% [markdown]
# # inisialisasi tokenizer

# %%
# inisialisasi tokenizer
tokenizer = Tokenizer(num_words=5000, oov_token='<OOV>')
tokenizer.fit_on_texts(data['Question'])

# %%
# fungsi untuk mengganti kata typo dengan kata yang paling mirip pada dataset
def correct_typo(word):
    max_score = -1
    correct_word = word
    for vocab_word in tokenizer.word_index:
        score = fuzz.ratio(word, vocab_word)
        if score > max_score:
            max_score = score
            correct_word = vocab_word
    return correct_word

# fungsi untuk mengoreksi typo pada kalimat
def correct_sentence(sentence):
    corrected_sentence = []
    words = sentence.split()
    for word in words:
        corrected_word = correct_typo(word)
        corrected_sentence.append(corrected_word)
    return ' '.join(corrected_sentence)

# fungsi untuk membersihkan dan memproses input pengguna
def preprocess_input(text):
    text = remove_stopwords(text)
    text = correct_sentence(text)
    return text

# %% [markdown]
# # encoding label Respon

# %%
encoder = LabelEncoder()
encoder.fit(data['Answer'])
encoded_labels = encoder.transform(data['Answer'])

# %% [markdown]
# # split data menjadi train dan validation set

# %%
train_size = int(len(data) * 0.8)
train_data = data[:train_size]
val_data = data[train_size:]

train_seq = tokenizer.texts_to_sequences(data['Question'])
val_seq = tokenizer.texts_to_sequences(val_data['Question'])

train_label_seq = encoded_labels[:train_size]
val_label_seq = encoded_labels[train_size:]

# %% [markdown]
# # padding sequence

# %%
train_seq = pad_sequences(train_seq, maxlen=100, truncating='post')
val_seq = pad_sequences(val_seq, maxlen=100, truncating='post')

# %% [markdown]
# # callback

# %%
class Callback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if logs.get('accuracy') is not None and logs.get('accuracy') > 0.998:
            print("\n\nAccuracy Has Been Achieved Around 99.8%, Training Stop!\n")
            self.model.stop_training = True

# %% [markdown]
# # MODEL

# %%
model = Sequential([
    Embedding(len(tokenizer.word_index)+1, 16, input_length=100),
    GlobalMaxPooling1D(),
    Dropout(0.2),
    Dense(512, activation='relu'),
    Dense(159, activation='softmax')
])
# compile model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# training model
history = model.fit(train_seq, encoded_labels, epochs=200,callbacks=[Callback()])
# Out:
# Epoch 1/200
# 5/5 [==============================] - 1s 8ms/step - loss: 5.0729 - accuracy: 0.0000e+00
# Epoch 2/200
# 5/5 [==============================] - 0s 9ms/step - loss: 5.0675 - accuracy: 0.0063
# Epoch 3/200
# 5/5 [==============================] - 0s 12ms/step - loss: 5.0636 - accuracy: 0.0316
# Epoch 4/200
# 5/5 [==============================] - 0s 9ms/step - loss: 5.0586 - accuracy: 0.0380
# Epoch 5/200
# 5/5 [==============================] - 0s 10ms/step - loss: 5.0535 - accuracy: 0.0759
# Epoch 6/200
# 5/5 [==============================] - 0s 11ms/step - loss: 5.0482 - accuracy: 0.0886
# Epoch 7/200
# 5/5 [==============================] - 0s 10ms/step - loss: 5.0400 - accuracy: 0.1139
# Epoch 8/200
# 5/5 [==============================] - 0s 11ms/step - loss: 5.0303 - accuracy: 0.1139
# Epoch 9/200
# 5/5 [==============================] - 0s 10ms/step - loss: 5.0175 - accuracy: 0.1519
# Epoch 10/200
# 5/5 [==============================] - 0s 10ms/step - loss: 5.0044 - accuracy: 0.1646
# Epoch 11/200
# 5/5 [==============================] - 0s 12ms/step - loss: 4.9855 - accuracy: 0.1962
# Epoch 12/200
# 5/5 [==============================] - 0s 8ms/step - loss: 4.9611 - accuracy: 0.2152
# Epoch 13/200
# 5/5 [==============================] - 0s 12ms/step - loss: 4.9357 - accuracy: 0.2532
# Epoch 14/200
# 5/5 [==============================] - 0s 10ms/step - loss: 4.9069 - accuracy: 0.2025
# Epoch 15/200
# 5/5 [==============================] - 0s 11ms/step - loss: 4.8666 - accuracy: 0.3165
# Epoch 16/200
# 5/5 [==============================] - 0s 10ms/step - loss: 4.8223 - accuracy: 0.2975
# Epoch 17/200
# 5/5 [==============================] - 0s 10ms/step - loss: 4.7714 - accuracy: 0.3101
# Epoch 18/200
# 5/5 [==============================] - 0s 10ms/step - loss: 4.7133 - accuracy: 0.2975
# Epoch 19/200
# 5/5 [==============================] - 0s 8ms/step - loss: 4.6454 - accuracy: 0.2848
200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.4235 - accuracy: 0.9051
# Epoch 99/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3721 - accuracy: 0.9177
# Epoch 100/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3725 - accuracy: 0.9241
# Epoch 101/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4161 - accuracy: 0.9051
# Epoch 102/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.3384 - accuracy: 0.9177
# Epoch 103/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.4344 - accuracy: 0.8924
# Epoch 104/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3771 - accuracy: 0.9051
# Epoch 105/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2954 - accuracy: 0.9494
# Epoch 106/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3759 - accuracy: 0.9304
# Epoch 107/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3725 - accuracy: 0.9177
# Epoch 108/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3702 - accuracy: 0.9241
# Epoch 109/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3258 - accuracy: 0.9430
# Epoch 110/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2738 - accuracy: 0.9367
# Epoch 111/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.3217 - accuracy: 0.9304
# Epoch 112/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.4381 - accuracy: 0.8608
# Epoch 113/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3790 - accuracy: 0.8924
# Epoch 114/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.3253 - accuracy: 0.9177
# Epoch 115/200
# 5/5 [==============================] - 0s 12ms/step - loss: 0.3057 - accuracy: 0.9241
# Epoch 116/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3125 - accuracy: 0.9177
# Epoch 117/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3445 - accuracy: 0.9177
# Epoch 118/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2483 - accuracy: 0.9430
# Epoch 119/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2964 - accuracy: 0.9557
# Epoch 120/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3799 - accuracy: 0.9177
# Epoch 121/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2915 - accuracy: 0.9051
# Epoch 122/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.3301 - accuracy: 0.9051
# Epoch 123/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2765 - accuracy: 0.9304
# Epoch 124/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2741 - accuracy: 0.9367
# Epoch 125/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3018 - accuracy: 0.9051
# Epoch 126/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2789 - accuracy: 0.9177
# Epoch 127/200
# 5/5 [==============================] - 0s 7ms/step - loss: 0.2656 - accuracy: 0.9367
# Epoch 128/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.2483 - accuracy: 0.9304
# Epoch 129/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2732 - accuracy: 0.9367
# Epoch 130/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2809 - accuracy: 0.9367
# Epoch 131/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.3432 - accuracy: 0.8987
# Epoch 132/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2697 - accuracy: 0.9367
# Epoch 133/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2632 - accuracy: 0.9241
# Epoch 134/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2404 - accuracy: 0.9367
# Epoch 135/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2326 - accuracy: 0.9494
# Epoch 136/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2609 - accuracy: 0.9430
# Epoch 137/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2490 - accuracy: 0.9367
# Epoch 138/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2800 - accuracy: 0.9177
# Epoch 139/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2343 - accuracy: 0.9367
# Epoch 140/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2535 - accuracy: 0.9241
# Epoch 141/200
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2656 - accuracy: 0.9367
# Epoch 142/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2370 - accuracy: 0.9367
# Epoch 143/200
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2714 - accuracy: 0.9367
# Epoch 144/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2300 - accuracy: 0.9304
# Epoch 145/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2620 - accuracy: 0.9114
# Epoch 146/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2575 - accuracy: 0.9051
# Epoch 147/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2591 - accuracy: 0.9367
# Epoch 148/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2833 - accuracy: 0.9051
# Epoch 149/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2900 - accuracy: 0.9304
# Epoch 150/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2509 - accuracy: 0.9241
# Epoch 151/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2188 - accuracy: 0.9557
# Epoch 152/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2318 - accuracy: 0.9430
# Epoch 153/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2403 - accuracy: 0.9241
# Epoch 154/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2239 - accuracy: 0.9367
# Epoch 155/200
# 5/5 [==============================] - 0s 7ms/step - loss: 0.2089 - accuracy: 0.9430
# Epoch 156/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2320 - accuracy: 0.9241
# Epoch 157/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2490 - accuracy: 0.9241
# Epoch 158/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2571 - accuracy: 0.8987
# Epoch 159/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2474 - accuracy: 0.9241
# Epoch 160/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2321 - accuracy: 0.9367
# Epoch 161/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2666 - accuracy: 0.9114
# Epoch 162/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2725 - accuracy: 0.9114
# Epoch 163/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2456 - accuracy: 0.9177
# Epoch 164/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2699 - accuracy: 0.9367
# Epoch 165/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1738 - accuracy: 0.9620
# Epoch 166/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1912 - accuracy: 0.9494
# Epoch 167/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1940 - accuracy: 0.9430
# Epoch 168/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2314 - accuracy: 0.9304
# Epoch 169/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2208 - accuracy: 0.9367
# Epoch 170/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1882 - accuracy: 0.9557
# Epoch 171/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2123 - accuracy: 0.9367
# Epoch 172/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2073 - accuracy: 0.9304
# Epoch 173/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2569 - accuracy: 0.9241
# Epoch 174/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1973 - accuracy: 0.9557
# Epoch 175/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2256 - accuracy: 0.9177
# Epoch 176/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1968 - accuracy: 0.9367
# Epoch 177/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2129 - accuracy: 0.9620
# Epoch 178/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2173 - accuracy: 0.9241
# Epoch 179/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2048 - accuracy: 0.9494
# Epoch 180/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2254 - accuracy: 0.9304
# Epoch 181/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1648 - accuracy: 0.9557
# Epoch 182/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1970 - accuracy: 0.9367
# Epoch 183/200
# 5/5 [==============================] - 0s 7ms/step - loss: 0.2219 - accuracy: 0.9430
# Epoch 184/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.2782 - accuracy: 0.9051
# Epoch 185/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1747 - accuracy: 0.9494
# Epoch 186/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1929 - accuracy: 0.9241
# Epoch 187/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1702 - accuracy: 0.9367
# Epoch 188/200
# 5/5 [==============================] - 0s 7ms/step - loss: 0.2010 - accuracy: 0.9367
# Epoch 189/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1933 - accuracy: 0.9620
# Epoch 190/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2074 - accuracy: 0.9304
# Epoch 191/200
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2114 - accuracy: 0.9430
# Epoch 192/200
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1725 - accuracy: 0.9557
# Epoch 193/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1584 - accuracy: 0.9557
# Epoch 194/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2152 - accuracy: 0.9367
# Epoch 195/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.1539 - accuracy: 0.9620
# Epoch 196/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.1921 - accuracy: 0.9367
# Epoch 197/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1903 - accuracy: 0.9494
# Epoch 198/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2154 - accuracy: 0.9494
# Epoch 199/200
# 5/5 [==============================] - 0s 12ms/step - loss: 0.2158 - accuracy: 0.9304
# Epoch 200/200
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1919 - accuracy: 0.9304

# %%
import matplotlib.pyplot as plt

# Plot utility
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.show()

# Plot the accuracy and results 
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %% [markdown]
# # TESTING

# %%
try:
    input_text = input('Masukkan pertanyaan: ')
    preprocessed_text = preprocess_input(input_text)
    input_seq = tokenizer.texts_to_sequences([preprocessed_text])
    input_seq = pad_sequences(input_seq, maxlen=100)
    predicted_label_seq = model.predict(input_seq)
    predicted_label = encoder.inverse_transform(predicted_label_seq.argmax(axis=-1))[0]
    print('Jawaban: ', predicted_label)
except:
    print("Bot : maaf saya tidak memahami maksud anda")
# Out:
# Masukkan pertanyaan: skolah penyebab depresi
# 1/1 [==============================] - 0s 31ms/step
# Jawaban:  Tidak hanya sekolah terkadang berkontribusi pada depresi, depresi juga dapat mengganggu sekolah. Selain itu, penelitian menunjukkan bahwa 75 persen dari semua kondisi kesehatan mental dimulai pada usia 24 tahun. Oleh karena itu, masa kuliah adalah waktu yang kritis untuk memahami dan membicarakan kesehatan mental remaja.
