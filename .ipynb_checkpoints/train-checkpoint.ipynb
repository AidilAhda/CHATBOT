# %%
import re
import pandas as pd
import numpy as np
import tensorflow as tf
from fuzzywuzzy import fuzz
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.layers import Dense, Embedding, LSTM,Dropout,Bidirectional,GlobalMaxPooling1D

# %% [markdown]
# # load dataset

# %%
data = pd.read_csv('Bot Dataset.csv')
data.head()
# Out:
#       tag                                           Question  \
# 0  user 1                           Apa itu penyakit mental?
# 1  user 2           Siapa yang mempengaruhi penyakit mental?
# 2  user 3              Apa yang menyebabkan penyakit mental?
# 3  user 4  Apa saja tanda -tanda peringatan penyakit mental?
# 4  user 5        Bisakah orang dengan penyakit mental pulih?
#
#                                               Answer
# 0  Penyakit mental adalah kondisi kesehatan yang ...
# 1  Diperkirakan bahwa penyakit mental mempengaruh...
# 2  Diperkirakan bahwa penyakit mental mempengaruh...
# 3  Gejala gangguan kesehatan mental bervariasi te...
# 4  Ketika penyembuhan dari penyakit mental, ident...

# %% [markdown]
# # inisialisasi stop words

# %%
stopwords = []
with open('stopwords.txt', encoding='utf-8') as f:
  for line in f:
    stopwords.append(line.strip())

# %%
# fungsi untuk menghilangkan stopwords
def remove_stopwords(text):
    text = text.lower()
    text = re.sub('[^a-zA-Z0-9\s]', '', text)
    temp = re.sub(r'[.,’"\'-?:!;]', '', text)
    text = re.sub(r'^Apa|^Saya|^Aku|^maukah|^Siapa|^Bagaimana|^Dimana|^Kapan|^Kenapa', '', text)
    words = [word for word in text.split() if word not in stopwords]
    return ' '.join(words)

# %%
# menghilangkan stopwords dari dataset
data['Question'] = data['Question'].apply(remove_stopwords)
print(data['Question'])
# Out:
# 0                             penyakit mental
# 1                mempengaruhi penyakit mental
# 2                 menyebabkan penyakit mental
# 3      tanda tanda peringatan penyakit mental
# 4                 orang penyakit mental pulih
#                         ...
# 153                                     stres
# 154                            berhasil hidup
# 155                                         p
# 156                           assalamualaikum
# 157                              teman curhat
# Name: Question, Length: 158, dtype: object

# %% [markdown]
# # inisialisasi tokenizer

# %%
# inisialisasi tokenizer
tokenizer = Tokenizer(num_words=5000, oov_token='<OOV>')
tokenizer.fit_on_texts(data['Question'])

# %%
# fungsi untuk mengganti kata typo dengan kata yang paling mirip pada dataset
def correct_typo(word):
    max_score = -1
    correct_word = word
    for vocab_word in tokenizer.word_index:
        score = fuzz.ratio(word, vocab_word)
        if score > max_score:
            max_score = score
            correct_word = vocab_word
    return correct_word

# fungsi untuk mengoreksi typo pada kalimat
def correct_sentence(sentence):
    corrected_sentence = []
    words = sentence.split()
    for word in words:
        corrected_word = correct_typo(word)
        corrected_sentence.append(corrected_word)
    return ' '.join(corrected_sentence)

# fungsi untuk membersihkan dan memproses input pengguna
def preprocess_input(text):
    text = remove_stopwords(text)
    text = correct_sentence(text)
    return text

# %% [markdown]
# # encoding label Respon

# %%
encoder = LabelEncoder()
encoder.fit(data['Answer'])
encoded_labels = encoder.transform(data['Answer'])

# %% [markdown]
# # split data menjadi train dan validation set

# %%
train_size = int(len(data) * 0.8)
train_data = data[:train_size]
val_data = data[train_size:]

train_seq = tokenizer.texts_to_sequences(train_data['Question'])
val_seq = tokenizer.texts_to_sequences(val_data['Question'])

train_label_seq = encoded_labels[:train_size]
val_label_seq = encoded_labels[train_size:]

# %% [markdown]
# # padding sequence

# %%
train_seq = pad_sequences(train_seq, maxlen=100, truncating='post')
val_seq = pad_sequences(val_seq, maxlen=100, truncating='post')

# %% [markdown]
# # callback

# %%
class Callback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if logs.get('accuracy') is not None and logs.get('accuracy') > 0.998:
            print("\n\nAccuracy Has Been Achieved Around 99.8%, Training Stop!\n")
            self.model.stop_training = True

# %% [markdown]
# # MODEL

# %%
model = Sequential([
    Embedding(len(tokenizer.word_index)+1, 16, input_length=100),
    GlobalMaxPooling1D(),
    Dropout(0.2),
    Dense(512, activation='relu'),
    Dense(159, activation='softmax')
])
# compile model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# training model
history = model.fit(train_seq, train_label_seq, epochs=200,callbacks=[Callback()])
# Out:
# Epoch 1/200
# 4/4 [==============================] - 1s 12ms/step - loss: 5.0716 - accuracy: 0.0000e+00
# Epoch 2/200
# 4/4 [==============================] - 0s 14ms/step - loss: 5.0639 - accuracy: 0.0079
# Epoch 3/200
# 4/4 [==============================] - 0s 13ms/step - loss: 5.0569 - accuracy: 0.0238
# Epoch 4/200
# 4/4 [==============================] - 0s 12ms/step - loss: 5.0510 - accuracy: 0.0159
# Epoch 5/200
# 4/4 [==============================] - 0s 9ms/step - loss: 5.0421 - accuracy: 0.0238
# Epoch 6/200
# 4/4 [==============================] - 0s 15ms/step - loss: 5.0324 - accuracy: 0.0635
# Epoch 7/200
# 4/4 [==============================] - 0s 9ms/step - loss: 5.0192 - accuracy: 0.0476
# Epoch 8/200
# 4/4 [==============================] - 0s 9ms/step - loss: 5.0014 - accuracy: 0.0714
# Epoch 9/200
# 4/4 [==============================] - 0s 12ms/step - loss: 4.9829 - accuracy: 0.0794
# Epoch 10/200
# 4/4 [==============================] - 0s 16ms/step - loss: 4.9610 - accuracy: 0.0952
# Epoch 11/200
# 4/4 [==============================] - 0s 10ms/step - loss: 4.9302 - accuracy: 0.1190
# Epoch 12/200
# 4/4 [==============================] - 0s 13ms/step - loss: 4.8976 - accuracy: 0.0952
# Epoch 13/200
# 4/4 [==============================] - 0s 11ms/step - loss: 4.8628 - accuracy: 0.1111
# Epoch 14/200
# 4/4 [==============================] - 0s 10ms/step - loss: 4.8243 - accuracy: 0.0952
# Epoch 15/200
# 4/4 [==============================] - 0s 10ms/step - loss: 4.7832 - accuracy: 0.1429
# Epoch 16/200
# 4/4 [==============================] - 0s 8ms/step - loss: 4.7366 - accuracy: 0.1429
# Epoch 17/200
# 4/4 [==============================] - 0s 11ms/step - loss: 4.6983 - accuracy: 0.1508
# Epoch 18/200
# 4/4 [==============================] - 0s 11ms/step - loss: 4.6461 - accuracy: 0.1429
# Epoch 19/200
# 4/4 [==============================] - 0s 10ms/step - loss: 4.6074 - accuracy: 0.1508
# Epoch 20/200
# 4/4 [==============================] - 0s 8ms/step - loss: 4.5524 - accuracy: 0.1984
# Epoch 21/200
# 4/4 [==============================] - 0s 12ms/step - loss: 4.4939 - accuracy: 0.2540
# Epoch 22/200
# 4/4 [==============================] - 0s 10ms/step - loss: 4.4331 - accuracy: 0.3571
# Epoch 23/200
200
# 4/4 [==============================] - 0s 22ms/step - loss: 0.4202 - accuracy: 0.9206
# Epoch 106/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3932 - accuracy: 0.9206
# Epoch 107/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3988 - accuracy: 0.9206
# Epoch 108/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4348 - accuracy: 0.9127
# Epoch 109/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4704 - accuracy: 0.8968
# Epoch 110/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3894 - accuracy: 0.8968
# Epoch 111/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3682 - accuracy: 0.9048
# Epoch 112/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3716 - accuracy: 0.9206
# Epoch 113/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3657 - accuracy: 0.8968
# Epoch 114/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3567 - accuracy: 0.9286
# Epoch 115/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3070 - accuracy: 0.9603
# Epoch 116/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3014 - accuracy: 0.9683
# Epoch 117/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3405 - accuracy: 0.9286
# Epoch 118/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3355 - accuracy: 0.9365
# Epoch 119/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3232 - accuracy: 0.9048
# Epoch 120/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3050 - accuracy: 0.9127
# Epoch 121/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3296 - accuracy: 0.8810
# Epoch 122/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2776 - accuracy: 0.9603
# Epoch 123/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3471 - accuracy: 0.9365
# Epoch 124/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3352 - accuracy: 0.9127
# Epoch 125/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3119 - accuracy: 0.9048
# Epoch 126/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3006 - accuracy: 0.9286
# Epoch 127/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2836 - accuracy: 0.9206
# Epoch 128/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2797 - accuracy: 0.9444
# Epoch 129/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3299 - accuracy: 0.8968
# Epoch 130/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3567 - accuracy: 0.9048
# Epoch 131/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3058 - accuracy: 0.9365
# Epoch 132/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3326 - accuracy: 0.9286
# Epoch 133/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2961 - accuracy: 0.9206
# Epoch 134/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3578 - accuracy: 0.9127
# Epoch 135/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2760 - accuracy: 0.9206
# Epoch 136/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2769 - accuracy: 0.9127
# Epoch 137/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2292 - accuracy: 0.9524
# Epoch 138/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2911 - accuracy: 0.9127
# Epoch 139/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3049 - accuracy: 0.9048
# Epoch 140/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3150 - accuracy: 0.9286
# Epoch 141/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2652 - accuracy: 0.9206
# Epoch 142/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2203 - accuracy: 0.9603
# Epoch 143/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2640 - accuracy: 0.9048
# Epoch 144/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2787 - accuracy: 0.9206
# Epoch 145/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3459 - accuracy: 0.8730
# Epoch 146/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2209 - accuracy: 0.9683
# Epoch 147/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2103 - accuracy: 0.9683
# Epoch 148/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2308 - accuracy: 0.9365
# Epoch 149/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2387 - accuracy: 0.9444
# Epoch 150/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2247 - accuracy: 0.9365
# Epoch 151/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2426 - accuracy: 0.9444
# Epoch 152/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2335 - accuracy: 0.9365
# Epoch 153/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2341 - accuracy: 0.9444
# Epoch 154/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2909 - accuracy: 0.9286
# Epoch 155/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3374 - accuracy: 0.8968
# Epoch 156/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3280 - accuracy: 0.9048
# Epoch 157/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2412 - accuracy: 0.9286
# Epoch 158/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1979 - accuracy: 0.9524
# Epoch 159/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2664 - accuracy: 0.9206
# Epoch 160/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2704 - accuracy: 0.9206
# Epoch 161/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2505 - accuracy: 0.9444
# Epoch 162/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2440 - accuracy: 0.9603
# Epoch 163/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2590 - accuracy: 0.9048
# Epoch 164/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2412 - accuracy: 0.9127
# Epoch 165/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2803 - accuracy: 0.9127
# Epoch 166/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2065 - accuracy: 0.9206
# Epoch 167/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1791 - accuracy: 0.9683
# Epoch 168/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2628 - accuracy: 0.9048
# Epoch 169/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2181 - accuracy: 0.9524
# Epoch 170/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2515 - accuracy: 0.9286
# Epoch 171/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2446 - accuracy: 0.9365
# Epoch 172/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2382 - accuracy: 0.9444
# Epoch 173/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2287 - accuracy: 0.9444
# Epoch 174/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2259 - accuracy: 0.9524
# Epoch 175/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1911 - accuracy: 0.9444
# Epoch 176/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2432 - accuracy: 0.9127
# Epoch 177/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2467 - accuracy: 0.9365
# Epoch 178/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1953 - accuracy: 0.9444
# Epoch 179/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1744 - accuracy: 0.9524
# Epoch 180/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2254 - accuracy: 0.9524
# Epoch 181/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2086 - accuracy: 0.9286
# Epoch 182/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1542 - accuracy: 0.9524
# Epoch 183/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1858 - accuracy: 0.9762
# Epoch 184/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1297 - accuracy: 0.9603
# Epoch 185/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2034 - accuracy: 0.9444
# Epoch 186/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1761 - accuracy: 0.9524
# Epoch 187/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1856 - accuracy: 0.9762
# Epoch 188/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1872 - accuracy: 0.9444
# Epoch 189/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1699 - accuracy: 0.9603
# Epoch 190/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1718 - accuracy: 0.9444
# Epoch 191/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1941 - accuracy: 0.9365
# Epoch 192/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1674 - accuracy: 0.9683
# Epoch 193/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1877 - accuracy: 0.9444
# Epoch 194/200
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1829 - accuracy: 0.9603
# Epoch 195/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2112 - accuracy: 0.9444
# Epoch 196/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1731 - accuracy: 0.9286
# Epoch 197/200
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1222 - accuracy: 0.9841
# Epoch 198/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1773 - accuracy: 0.9444
# Epoch 199/200
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1766 - accuracy: 0.9365
# Epoch 200/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2416 - accuracy: 0.9286

# %%
import matplotlib.pyplot as plt

# Plot utility
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.show()

# Plot the accuracy and results 
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %% [markdown]
# # TESTING

# %%
try:
    input_text = input('Masukkan pertanyaan: ')
    preprocessed_text = preprocess_input(input_text)
    input_seq = tokenizer.texts_to_sequences([preprocessed_text])
    input_seq = pad_sequences(input_seq, maxlen=100)
    predicted_label_seq = model.predict(input_seq)
    predicted_label = encoder.inverse_transform(predicted_label_seq.argmax(axis=-1))[0]
    print('Jawaban: ', predicted_label)
except:
    print("Bot : maaf saya tidak memahami maksud anda")
# Out:
# Masukkan pertanyaan: bagaimana mendapatkan banuan
# 1/1 [==============================] - 0s 47ms/step
# Jawaban:  Di mana Anda mencari bantuan akan tergantung pada sifat masalah dan/atau gejala dan apa yang paling cocok untuk Anda. Seringkali, tempat terbaik untuk memulai adalah dengan berbicara dengan seseorang yang Anda percayai tentang kekhawatiran Anda, seperti anggota keluarga, teman, pendeta, penyedia layanan kesehatan, atau profesional lainnya. Memiliki dukungan sosial ini sangat penting dalam penyembuhan dari penyakit mental, dan Anda akan dapat meminta mereka untuk rujukan atau rekomendasi untuk praktisi kesehatan mental tepercaya. Cari sumber daya kesehatan mental di daerah Anda.
# Kedua, ada orang dan tempat di seluruh Nebraska yang menyediakan layanan untuk berbicara, mendengarkan, dan membantu Anda dalam perjalanan Anda menuju pemulihan. Ketiga, banyak orang menemukan peer mendukung alat yang bermanfaat yang dapat membantu pemulihan mereka. Ada berbagai organisasi yang menawarkan kelompok pendukung untuk konsumen, anggota keluarga mereka, dan teman -teman. Beberapa kelompok pendukung dipimpin rekan sementara yang lain mungkin dipimpin oleh seorang profesional kesehatan mental.
